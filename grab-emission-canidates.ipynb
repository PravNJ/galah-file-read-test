# %%
import numpy as np
import pandas as pd
import astropy.io.fits as pyfits
import matplotlib.pyplot as plt
import glob
from astropy.table import Table 
from spectres import spectres

# %%
missing_data=pd.read_csv("/home/praveen/Dropbox/Masters/python-code/galah-file-read-test/data/missing_data_products_all.txt",delim_whitespace=True)

# %%
missing_data.head()
# Out:
#              survey  data_release      source_name  \
# GALAH Data  Release             3  131116001001192
#       Data  Release             3  131116001001279
#       Data  Release             3  131118001901243
#       Data  Release             3  131118001901332
#       Data  Release             3  131118002901190
#
#                                       schema_key
# GALAH Data  galah.dr3.spectra.hermes.spectrum_1d
#       Data  galah.dr3.spectra.hermes.spectrum_1d
#       Data  galah.dr3.spectra.hermes.spectrum_1d
#       Data  galah.dr3.spectra.hermes.spectrum_1d
#       Data  galah.dr3.spectra.hermes.spectrum_1d

# %%
missing_data_np=missing_data["source_name"].to_numpy()

# %%
df_missing_data = pd.DataFrame(data=missing_data_np, columns=["sobject_id"])

# %%
df_missing_data.head()
# Out:
#         sobject_id
# 0  131116001001192
# 1  131116001001279
# 2  131118001901243
# 3  131118001901332
# 4  131118002901190

# %%
data = Table.read('/home/praveen/Dropbox/Masters/emission-mnras-cotar/data.fits', format='fits')

# %%
df_full = data.to_pandas()

# %%
df_emiss_full = df_full.loc[df_full['emiss'] == True]

# %%
df_emiss_full_ids = df_emiss_full[["sobject_id"]].copy()

# %%
df_emiss_full_ids.head()
# Out:
#           sobject_id
# 231  131116000501262
# 332  131116000501383
# 420  131116001001192
# 432  131116001001213
# 462  131116001001279

# %%
df_temp = pd.merge(df_emiss_full_ids, df_missing_data, how='outer', indicator=True)

# %%
df_temp.head()
# Out:
#         sobject_id     _merge
# 0  131116000501262  left_only
# 1  131116000501383  left_only
# 2  131116001001192       both
# 3  131116001001213  left_only
# 4  131116001001279       both

# %%
df_final_sobject_ids_temp = df_temp.loc[df_temp['_merge'] == "left_only"]

# %%
df_final_sobject_ids_temp.head()
# Out:
#         sobject_id     _merge
# 0  131116000501262  left_only
# 1  131116000501383  left_only
# 3  131116001001213  left_only
# 5  131116001001379  left_only
# 8  131118002401234  left_only

# %%
df1 = df_final_sobject_ids_temp.drop('_merge', 1)
# Out:
# /tmp/ipykernel_22153/408999226.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   df1 = df_final_sobject_ids_temp.drop('_merge', 1)

# %%
df1.head()
# Out:
#         sobject_id
# 0  131116000501262
# 1  131116000501383
# 3  131116001001213
# 5  131116001001379
# 8  131118002401234

# %%
df_missing_norm = pd.read_csv("/home/praveen/Dropbox/Masters/python-code/galah-file-read-test/data/GALAH_DR3_list_missing_normalized_spectra_v2.csv", header=None) #GALAH objects with missing normalised spectra 
df_missing_norm.columns = ['sobject_id']

# %%
df_temp = pd.merge(df1, df_missing_norm, how='outer', indicator=True)

# %%
df_temp
# Out:
#            sobject_id      _merge
# 0     131116000501262   left_only
# 1     131116000501383   left_only
# 2     131116001001213   left_only
# 3     131116001001379   left_only
# 4     131118002401234   left_only
# ...               ...         ...
# 8576  181226003601116  right_only
# 8577  181226003601199  right_only
# 8578  181226004101074  right_only
# 8579  181226004101265  right_only
# 8580  181226004601235  right_only
#
# [8581 rows x 2 columns]

# %%
df2 = df_temp.loc[df_temp['_merge'] == "left_only"].drop(["_merge"], axis=1)

# %%
df2
# Out:
#            sobject_id
# 0     131116000501262
# 1     131116000501383
# 2     131116001001213
# 3     131116001001379
# 4     131118002401234
# ...               ...
# 8349  190225004801232
# 8350  190225005301010
# 8351  190225005301142
# 8352  190225005301225
# 8353  190225005301392
#
# [8354 rows x 1 columns]

# %%
df2.to_csv("final_emission_list.csv")

# %%
sobject_ids=df2["sobject_id"].to_numpy().tolist()

# %%
df3=pd.read_csv("final_emission_list.csv")

# %%
df4 = df3[["sobject_id"]].copy()

# %%
df4
# Out:
#            sobject_id
# 0     131116000501262
# 1     131116000501383
# 2     131116001001213
# 3     131116001001379
# 4     131118002401234
# ...               ...
# 7364  171230004601352
# 7365  171230005101058
# 7366  171230005101079
# 7367  171230005801087
# 7368  171230005801232
#
# [7369 rows x 1 columns]

# %%
sobject_ids=df4["sobject_id"].to_numpy().tolist()

# %%
#/home/praveen/Documents/all_data

# %%
GRID_SIZE = 0.06
LOWER_LAMBDA = 6472.5
UPPER_LAMBDA = 6740

# %%
regrid = np.arange(LOWER_LAMBDA, UPPER_LAMBDA, GRID_SIZE)

# %%
def read_spectra(sobject_id):
    fits_files = [[],[],[],[]]
    for each_ccd in [1,2,3,4]:
        fits_files[each_ccd-1] = glob.glob("/home/praveen/Documents/all_data/"+str(sobject_id)+str(each_ccd)+".fits") #this is reading fits files from file and not downloading directly 

    spectrum = dict()
    for each_ccd in [1,2,3,4]: #GALAH uses indexing from 1 - 4
        if fits_files[each_ccd-1]!=[]: #just using zero indexing here 
            fits = pyfits.open(fits_files[each_ccd-1][0]) 
            
            # Extension 0: Reduced spectrum
            # Extension 1: Relative error spectrum
            # Extension 4: Normalised spectrum, NB: cut for CCD4

            # Extract wavelength grid for the reduced spectrum
            start_wavelength = fits[0].header["CRVAL1"]
            dispersion       = fits[0].header["CDELT1"]
            nr_pixels        = fits[0].header["NAXIS1"]
            reference_pixel  = fits[0].header["CRPIX1"]

            if reference_pixel == 0:
                reference_pixel = 1
            spectrum['wave_red_'+str(each_ccd)] = ((np.arange(0,nr_pixels)--reference_pixel+1)*dispersion+start_wavelength) #this is the reduced spectrum 

            # Extract wavelength grid for the normalised spectrum
            start_wavelength = fits[4].header["CRVAL1"]
            dispersion       = fits[4].header["CDELT1"]
            nr_pixels        = fits[4].header["NAXIS1"]
            reference_pixel  = fits[4].header["CRPIX1"]

            if reference_pixel == 0:
                reference_pixel=1
            spectrum['wave_norm_'+str(each_ccd)] = ((np.arange(0,nr_pixels)--reference_pixel+1)*dispersion+start_wavelength) #this is the normalised spectrum 

            spectrum['sob_red_'+str(each_ccd)]  = np.array(fits[0].data)
            spectrum['uob_red_'+str(each_ccd)]  = np.array(fits[0].data * fits[1].data)

            spectrum['sob_norm_'+str(each_ccd)] = np.array(fits[4].data)
            if each_ccd != 4:
                spectrum['uob_norm_'+str(each_ccd)] = np.array(fits[4].data * fits[1].data)
            else:
                # for normalised error of CCD4, only used appropriate parts of error spectrum
                spectrum['uob_norm_4'] = np.array(fits[4].data * (fits[1].data)[-len(spectrum['sob_norm_4']):])

            fits.close()
        else:
            spectrum['wave_red_'+str(each_ccd)] = []
            spectrum['wave_norm_'+str(each_ccd)] = []
            spectrum['sob_red_'+str(each_ccd)] = []
            spectrum['sob_norm_'+str(each_ccd)] = []
            spectrum['uob_red_'+str(each_ccd)] = []
            spectrum['uob_norm_'+str(each_ccd)] = []
    
    spectrum['wave_red'] = np.concatenate(([spectrum['wave_red_'+str(each_ccd)] for each_ccd in [1,2,3,4]]))
    spectrum['wave_norm'] = np.concatenate(([spectrum['wave_norm_'+str(each_ccd)] for each_ccd in [1,2,3,4]]))
    spectrum['sob_red'] = np.concatenate(([spectrum['sob_red_'+str(each_ccd)] for each_ccd in [1,2,3,4]]))
    spectrum['sob_norm'] = np.concatenate(([spectrum['sob_norm_'+str(each_ccd)] for each_ccd in [1,2,3,4]]))
    spectrum['uob_red'] = np.concatenate(([spectrum['uob_red_'+str(each_ccd)] for each_ccd in [1,2,3,4]]))
    spectrum['uob_norm'] = np.concatenate(([spectrum['uob_norm_'+str(each_ccd)] for each_ccd in [1,2,3,4]]))

    return spectrum 
    
    #returns a 30 "row" dict of numpy array per row 'wave_red_x' is the key for the key value pair
    #camera 3 will be the more useful canmera for Li spectra

# %%
spectra = {}
spectra['read_spec'] = []

# %%
sobject_ids = [131123003001096, 140311006601089, 140413005401145]

# %%
for i in range(len(sobject_ids)):
    spectrum = read_spectra(sobject_ids[i]) #spectrum['sob_norm_'+str(camera)]
    spectra['read_spec'].append(spectrum['sob_norm_3'])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_22153/3503581696.py in <module>
#       1 for i in range(len(sobject_ids)):
# ----> 2     spectrum = read_spectra(sobject_ids[i]) #spectrum['sob_norm_'+str(camera)]
#       3     spectra['read_spec'].append(spectrum['sob_norm_3'])
#
# /tmp/ipykernel_22153/1175406774.py in read_spectra(sobject_id)
#      24
#      25             # Extract wavelength grid for the normalised spectrum
# ---> 26             start_wavelength = fits[4].header["CRVAL1"]
#      27             dispersion       = fits[4].header["CDELT1"]
#      28             nr_pixels        = fits[4].header["NAXIS1"]
#
# ~/anaconda3/envs/masters-thesis/lib/python3.8/site-packages/astropy/io/fits/hdu/hdulist.py in __getitem__(self, key)
#     322             # Raise a more helpful IndexError if the file was not fully read.
#     323             if self._read_all:
# --> 324                 raise e
#     325             else:
#     326                 raise IndexError('HDU not found, possibly because the index '
#
# ~/anaconda3/envs/masters-thesis/lib/python3.8/site-packages/astropy/io/fits/hdu/hdulist.py in __getitem__(self, key)
#     317         # instead
#     318         try:
# --> 319             return self._try_while_unread_hdus(super().__getitem__,
#     320                                                self._positive_index_of(key))
#     321         except IndexError as e:
#
# ~/anaconda3/envs/masters-thesis/lib/python3.8/site-packages/astropy/io/fits/hdu/hdulist.py in _try_while_unread_hdus(self, func, *args, **kwargs)
#    1134         while True:
#    1135             try:
# -> 1136                 return func(*args, **kwargs)
#    1137             except Exception:
#    1138                 if self._read_next_hdu():
#
# IndexError: list index out of range

# %%
spectra['read_spec']
# Out:
# [array([0.97637316, 0.98607529, 1.00008301, ..., 0.95826437, 0.94472458,
#         0.90487861]),
#  array([1.03711819, 1.04724289, 1.06785678, ..., 0.98376626, 0.9222493 ,
#         0.9529037 ]),
#  array([0.99184857, 0.96991195, 0.95798169, ..., 1.07005153, 1.04529462,
#         1.04319349]),
#  array([0.96005216, 0.9864934 , 0.98102335, ..., 0.98551172, 1.03933471,
#         1.04218208]),
#  array([1.07122999, 1.07448977, 1.0465883 , ..., 1.07532107, 1.04722289,
#         1.02215217]),
#  array([0.9431149 , 0.97428987, 0.98914246, ..., 1.01557591, 1.03602412,
#         1.01802273]),
#  array([0.96952635, 0.96903509, 0.95862503, ..., 0.99055677, 0.9916224 ,
#         0.99970385]),
#  array([0.97844052, 0.99291587, 0.99945905, ..., 0.98802798, 0.98932043,
#         0.96722354]),
#  array([1.06468714, 1.06306572, 1.03917726, ..., 1.08526916, 1.14515582,
#         1.00577076]),
#  array([1.00864268, 1.00736526, 1.01947545, ..., 1.00188861, 1.00698263,
#         0.99513662]),
#  array([0.97789376, 0.98148274, 0.98596956, ..., 0.99294478, 0.98442076,
#         0.98587386]),
#  [],
#  [],
#  array([0.95790619, 0.94187488, 0.91763512, ..., 0.99751812, 0.96804462,
#         0.98737   ]),
#  array([1.16161873, 1.13202554, 1.10939322, ..., 0.96533303, 0.91123716,
#         0.90493283]),
#  array([1.0551118 , 0.98562451, 0.97676695, ..., 0.98857771, 1.00114403,
#         0.92416999]),
#  array([0.99712705, 0.99632514, 1.00360745, ..., 1.00381495, 0.99694323,
#         0.97320329]),
#  array([1.00294781, 1.00574643, 1.0116787 , ..., 0.99285879, 0.99354777,
#         0.99265782]),
#  array([0.97479073, 0.99836388, 1.01672997, ..., 0.98048421, 0.97835786,
#         0.97115232]),
#  [],
#  [],
#  array([0.97843375, 0.98682807, 0.99630321, ..., 0.94943988, 0.9965362 ,
#         1.00116125]),
#  array([1.02411872, 1.03396951, 1.04684188, ..., 0.98120243, 0.97871313,
#         0.95605877]),
#  array([0.96477933, 1.0034245 , 0.99960691, ..., 0.99128724, 0.99531516,
#         1.01473457]),
#  array([0.97173158, 1.0023171 , 0.99474692, ..., 1.03514879, 0.97218407,
#         1.02539283]),
#  array([0.95378309, 0.98459015, 0.97512786, ..., 1.02458255, 1.01278023,
#         0.97514497]),
#  array([0.99557893, 0.97019977, 0.97344163, ..., 0.99236869, 0.96811126,
#         0.91779449]),
#  array([1.03764835, 1.02274357, 1.01959193, ..., 1.02150355, 0.93506931,
#         0.85942706]),
#  array([1.01727573, 0.99072055, 1.00339049, ..., 0.9359016 , 0.94563678,
#         0.92578512]),
#  array([0.99789356, 1.01573215, 1.02451498, ..., 0.95591853, 0.94966743,
#         0.95769361]),
#  array([0.96946617, 0.97912595, 0.99120541, ..., 1.00500885, 1.00414753,
#         1.01024293]),
#  array([1.01304524, 0.99820123, 0.99599543, ..., 0.98971899, 0.99148863,
#         0.99909118]),
#  [],
#  array([0.97947317, 0.97152226, 0.98706928, ..., 0.98213681, 0.9577566 ,
#         0.99119989]),
#  array([0.95368189, 0.97251633, 0.99961638, ..., 0.95744965, 1.01329836,
#         1.01827393]),
#  array([0.87300549, 0.87162613, 0.84287566, ..., 0.94308724, 0.92582789,
#         0.95194444]),
#  array([0.97522998, 0.98954688, 0.9788143 , ..., 1.02270684, 1.01026099,
#         0.99398162]),
#  [],
#  array([0.99534629, 1.03359026, 1.03037399, ..., 1.00668772, 0.9795727 ,
#         1.00806108]),
#  array([0.97410433, 0.94959507, 1.00478048, ..., 0.97452152, 0.98837082,
#         1.00104995]),
#  array([0.98867825, 0.98868517, 1.01283436, ..., 0.98513281, 0.97025893,
#         1.00993281]),
#  array([0.98122863, 0.98943089, 0.97551224, ..., 1.00051604, 0.98750188,
#         0.99592937]),
#  array([1.02601664, 0.97758942, 0.95671152, ..., 0.99634559, 1.01034112,
#         1.00242877]),
#  array([1.05672313, 1.04247632, 1.04812721, ..., 1.00872874, 1.04031425,
#         1.02929616]),
#  array([1.02864085, 0.99850754, 0.99368569, ..., 1.06358033, 1.03597111,
#         1.01965627]),
#  array([0.94549381, 0.98964472, 1.029037  , ..., 0.98672821, 1.03675352,
#         1.10675125]),
#  array([1.02912147, 1.04146299, 1.02553459, ..., 0.98516284, 1.02494272,
#         0.99664996]),
#  array([1.01079756, 1.03256306, 1.01623593, ..., 0.96089193, 0.97383793,
#         0.93510753]),
#  array([1.03660658, 1.0178873 , 1.01035911, ..., 1.01892464, 0.99962902,
#         1.01968018]),
#  array([1.00191675, 1.01641677, 1.00266946, ..., 0.98268888, 0.95791353,
#         0.98942095]),
#  array([0.99333782, 1.01338248, 1.00071529, ..., 1.01990274, 1.01891498,
#         1.04196625]),
#  array([1.01559513, 1.01066046, 0.99557426, ..., 0.97633752, 0.96996158,
#         0.99473843]),
#  array([1.02135139, 1.0244805 , 1.02011857, ..., 0.99607341, 0.99530964,
#         0.96835527]),
#  array([0.98512614, 0.9932617 , 0.99245659, ..., 0.98845958, 0.98392609,
#         0.99505764]),
#  array([1.00356665, 1.00475434, 1.00636035, ..., 1.00934316, 1.0068002 ,
#         0.99888147]),
#  array([0.9974661 , 0.98727838, 0.98926552, ..., 1.03883291, 1.04032344,
#         1.0316762 ]),
#  array([1.05626011, 1.06068355, 1.06005399, ..., 0.9885452 , 0.98794987,
#         0.94653525]),
#  array([1.05483976, 1.12396582, 1.13269092, ..., 1.01669117, 0.98595296,
#         0.96367966]),
#  array([1.06569718, 1.04565103, 1.01938864, ..., 1.00405664, 1.00391628,
#         1.01257203]),
#  [],
#  array([0.97848326, 0.97311398, 0.974954  , ..., 0.98504521, 0.99093715,
#         0.95786703]),
#  array([1.00126345, 0.99635776, 0.99835784, ..., 0.99162171, 0.99468463,
#         1.0026667 ]),
#  array([0.99551002, 1.01607806, 1.0214786 , ..., 0.97436049, 0.96396195,
#         0.95405416]),
#  array([0.97483629, 0.97736835, 0.98029437, ..., 0.95783924, 0.96328292,
#         0.97587135]),
#  array([0.99434338, 1.01153603, 1.00757113, ..., 0.869672  , 0.87651484,
#         0.87546191]),
#  [],
#  [],
#  array([0.86569145, 0.86833786, 0.87805466, ..., 0.99857499, 1.012476  ,
#         1.00507399]),
#  array([0.78884234, 0.78354768, 0.78972915, ..., 0.99495408, 0.98328994,
#         0.94693275]),
#  array([0.92990748, 0.91224678, 0.91895903, ..., 0.99626975, 1.02650927,
#         1.01374725]),
#  array([0.9333478 , 0.92371906, 0.94588933, ..., 0.96903944, 0.99230575,
#         0.98651158]),
#  array([0.98882337, 0.98904554, 0.99341596, ..., 1.00082381, 0.99142593,
#         0.99196115]),
#  array([0.88606978, 0.8855331 , 0.91985056, ..., 1.05261219, 1.04672354,
#         1.00879372]),
#  array([1.01288962, 1.00603033, 1.01490009, ..., 0.96573009, 0.95611495,
#         0.93284271]),
#  [],
#  array([0.98292552, 1.01047952, 0.9947196 , ..., 0.95613826, 0.9693389 ,
#         0.96190198]),
#  array([1.02682591, 1.01612129, 0.99719638, ..., 1.01281376, 0.98787127,
#         0.94532475]),
#  array([0.97909903, 0.97901533, 0.97990919, ..., 0.973879  , 1.03770247,
#         1.0323183 ]),
#  array([1.00452098, 0.98237945, 1.00337279, ..., 0.98367011, 0.9433971 ,
#         0.97760151]),
#  [],
#  array([1.00003386, 1.00967924, 1.0104041 , ..., 0.99562274, 1.00084178,
#         0.96894156]),
#  array([0.96091973, 1.00327248, 1.02031953, ..., 1.01822817, 1.00825364,
#         1.02473042]),
#  array([0.97647558, 1.02613939, 1.00695831, ..., 1.04658502, 1.04132326,
#         1.05864095]),
#  array([0.99060167, 0.99150731, 0.99432603, ..., 0.98632535, 0.99979599,
#         0.99219041]),
#  array([1.00930002, 0.98991543, 0.98434167, ..., 0.96900171, 0.96618781,
#         0.95664947]),
#  array([1.01949448, 1.02070061, 1.01204957, ..., 1.0022493 , 1.00490472,
#         0.98686189]),
#  array([1.03037227, 1.02640262, 1.02599896, ..., 1.00236408, 0.9918715 ,
#         0.99104694]),
#  array([1.02508188, 1.02202087, 1.00518323, ..., 0.99656406, 0.97274858,
#         0.96246608]),
#  [],
#  array([0.98130873, 0.98698582, 0.95717645, ..., 1.00954163, 0.99809276,
#         1.02374253]),
#  array([0.97250518, 1.00360343, 1.00594768, ..., 0.98143623, 0.99454991,
#         1.00699011]),
#  array([1.03171415, 1.03006027, 1.0305856 , ..., 0.97113975, 0.96492762,
#         1.01803599]),
#  [],
#  array([0.98422823, 0.9636226 , 0.95827511, ..., 0.99526787, 0.98426519,
#         0.97950883]),
#  array([1.00248639, 1.00928582, 1.02583042, ..., 0.9982512 , 1.01080569,
#         0.97886388]),
#  array([1.02252091, 1.00226303, 1.00382384, ..., 0.97527187, 0.97250686,
#         0.9755818 ]),
#  array([0.98568184, 0.9865065 , 1.0086963 , ..., 0.98423878, 0.99867972,
#         1.00916289]),
#  array([0.96592521, 0.99640438, 0.99436485, ..., 0.99846843, 1.00107369,
#         0.97819318]),
#  array([1.12766401, 1.13660226, 1.14715668, ..., 0.97795129, 0.97576345,
#         0.97435735]),
#  array([1.08254362, 1.09824564, 1.03913121, ..., 0.88785021, 0.95071682,
#         0.9358795 ]),
#  array([0.9732184 , 1.0130755 , 0.99082108, ..., 0.89489257, 0.94634509,
#         0.99936255]),
#  array([1.06506714, 1.07924593, 1.07214425, ..., 1.03586013, 1.01449625,
#         1.01648859]),
#  array([1.0441519 , 1.04831926, 1.048028  , ..., 0.96728081, 0.96459919,
#         0.92579379]),
#  array([0.98127045, 0.99763715, 1.01856824, ..., 1.02301749, 1.02478152,
#         1.02049509]),
#  array([0.99355112, 1.01347716, 1.00218084, ..., 0.99977334, 0.9949623 ,
#         0.97114143]),
#  array([1.00282708, 1.00925045, 1.01368137, ..., 0.93924738, 0.967799  ,
#         0.96038462]),
#  array([1.06654967, 1.03439608, 0.9976166 , ..., 0.90381923, 0.83314408,
#         0.80871101]),
#  array([1.04045585, 1.06977821, 1.05365944, ..., 0.94888184, 0.88744534,
#         0.87738094]),
#  array([0.97667359, 0.99837171, 1.01233926, ..., 0.96363093, 0.98961563,
#         0.963765  ]),
#  array([1.01293885, 1.03702834, 1.03221156, ..., 1.02372887, 1.06199924,
#         1.07750251]),
#  [],
#  array([1.13598897, 1.06862167, 1.03461763, ..., 0.96162954, 0.9749977 ,
#         0.97169912]),
#  array([0.83253693, 0.83136606, 0.88110754, ..., 1.01504458, 0.95659298,
#         0.97421094]),
#  array([0.98157065, 0.98939029, 0.9943525 , ..., 0.99946211, 1.00380795,
#         0.9944861 ]),
#  array([0.97928222, 1.02314405, 1.02055806, ..., 0.99867008, 0.96694455,
#         0.91839668]),
#  array([0.98320203, 0.99176948, 0.98471499, ..., 0.99071532, 0.99052512,
#         0.99057284]),
#  array([1.07171141, 1.01222503, 0.99268843, ..., 1.02777059, 1.00037598,
#         0.98004594]),
#  array([1.06091397, 1.01901237, 1.00037125, ..., 1.01989481, 1.00008741,
#         0.98840615]),
#  array([1.15497725, 1.05659251, 1.00682215, ..., 0.96710484, 0.92471653,
#         0.9779258 ]),
#  array([0.78381573, 0.81421978, 0.82454005, ..., 0.98994057, 0.93310786,
#         0.92711541]),
#  array([0.99964481, 0.98301576, 0.97375789, ..., 0.96935621, 0.97835514,
#         0.96668515]),
#  array([1.03870771, 0.98265484, 0.96479497, ..., 1.04577307, 0.98352004,
#         0.98007286]),
#  array([1.02150824, 1.06492384, 1.05737911, ..., 0.985262  , 1.01701548,
#         0.99496307]),
#  array([0.93586059, 0.96306769, 0.95912646, ..., 0.97261957, 0.93041265,
#         0.91010481]),
#  array([0.98723032, 1.01119945, 1.02635903, ..., 0.98239405, 0.97862486,
#         0.98939004]),
#  array([0.99988398, 0.98854292, 0.98473119, ..., 0.97264698, 0.97185281,
#         0.96914382]),
#  array([0.98687976, 0.99609974, 0.99973605, ..., 1.00279882, 1.00315501,
#         1.00238649]),
#  array([1.19735357, 1.20693691, 1.09838211, ..., 0.91125141, 0.8914307 ,
#         0.81943359]),
#  array([1.01357342, 1.02069766, 1.00513647, ..., 0.9961042 , 1.01170409,
#         1.04185794]),
#  array([1.0480141 , 1.03732481, 1.01235228, ..., 0.94771401, 0.94253005,
#         0.94060893]),
#  array([1.03146407, 1.04216388, 1.0264363 , ..., 1.02347214, 1.01967192,
#         1.00115661]),
#  array([1.3400509 , 1.11496957, 1.01491487, ..., 0.8915756 , 0.97906358,
#         0.97696557]),
#  array([0.99385242, 0.98760794, 1.0013303 , ..., 0.9979707 , 0.97596257,
#         0.99003364]),
#  array([0.99330045, 0.98694452, 0.99086591, ..., 1.02534101, 1.05846058,
#         1.00290948]),
#  array([0.96041661, 0.96761455, 0.95757061, ..., 1.01619752, 1.0274849 ,
#         1.03530959]),
#  array([1.00519897, 0.98788878, 1.0045639 , ..., 1.00218821, 0.98628947,
#         1.00881955]),
#  array([0.87030275, 0.89145192, 0.91395927, ..., 0.9746507 , 0.98202868,
#         0.98839573]),
#  array([0.98340515, 0.96493267, 0.97875374, ..., 0.97708926, 0.93960305,
#         0.88027668]),
#  array([0.99270036, 1.04029003, 1.08529146, ..., 0.91282354, 0.92829949,
#         0.95779883]),
#  array([0.98938271, 0.98457327, 0.98902993, ..., 0.95238373, 0.93711724,
#         0.93548983]),
#  array([0.97957719, 0.99817105, 1.00086867, ..., 0.93569963, 0.92236447,
#         0.9225409 ]),
#  array([0.99023513, 0.99505006, 0.99875378, ..., 0.89471041, 0.87650343,
#         0.8559034 ]),
#  array([1.00792965, 1.01799732, 1.03561921, ..., 1.01989174, 1.0129121 ,
#         1.01728008]),
#  array([1.03496309, 1.08944326, 1.08135556, ..., 0.93649339, 0.96623487,
#         0.9793226 ]),
#  array([0.99891349, 0.99151227, 0.99897373, ..., 0.99951344, 1.01561785,
#         1.04538006]),
#  array([1.02315281, 1.00815792, 1.01797902, ..., 1.00837911, 1.01047149,
#         0.99510568]),
#  array([1.02346505, 1.03371908, 1.01842677, ..., 1.00832855, 0.99237964,
#         0.99444313]),
#  array([0.60254846, 0.60804751, 0.59787234, ..., 0.32351643, 0.3377772 ,
#         0.33915142]),
#  [],
#  array([0.97786391, 0.99504643, 1.03175973, ..., 0.9735433 , 0.98823855,
#         1.01580905]),
#  array([0.98018977, 0.98899343, 0.99880823, ..., 1.00372795, 0.99089515,
#         0.93519445]),
#  array([1.03697832, 0.99689962, 1.0121548 , ..., 0.95737293, 0.96552515,
#         0.98456408]),
#  array([1.04644364, 1.01988479, 0.9983525 , ..., 1.0037972 , 1.00444832,
#         0.96838303]),
#  array([1.08084056, 1.12597395, 1.13734832, ..., 1.01181641, 1.01438229,
#         0.9430541 ]),
#  array([1.08575983, 1.08768006, 1.08890964, ..., 0.98653093, 0.99971435,
#         0.98019765]),
#  array([1.01467209, 0.99180681, 0.96454692, ..., 0.93548418, 0.92118394,
#         0.89167438]),
#  array([1.00589895, 0.98414861, 0.97851521, ..., 1.01331159, 0.97899583,
#         1.00651756]),
#  array([0.98091841, 0.99419596, 1.00063388, ..., 1.03144065, 1.00102546,
#         0.98942663]),
#  array([0.98630811, 0.9898442 , 0.98124747, ..., 0.99526117, 0.98571185,
#         0.97348496]),
#  [],
#  array([1.05697691, 1.01535312, 1.02029084, ..., 1.04658754, 1.02766691,
#         1.00510121]),
#  array([0.95763152, 0.95419405, 0.98541577, ..., 0.99966799, 1.00476918,
#         0.94611539]),
#  array([1.0472991 , 1.04886759, 1.02903012, ..., 0.9942755 , 1.00485401,
#         1.02270154]),
#  array([1.02810194, 1.01382625, 0.99316457, ..., 1.00663461, 0.99720742,
#         0.96767256]),
#  array([1.03837424, 1.04706194, 1.0637775 , ..., 0.97564913, 0.98014005,
#         0.93083876]),
#  array([0.97622071, 0.96014011, 0.94910583, ..., 0.75945039, 0.75987436,
#         0.72419123]),
#  array([1.00498958, 0.9604501 , 0.98028353, ..., 0.85305786, 0.85589289,
#         0.85039405]),
#  array([1.01819397, 0.97918757, 0.95029162, ..., 0.81236289, 0.8030207 ,
#         0.77565796]),
#  array([1.03582801, 0.98716503, 0.95002637, ..., 0.89540512, 0.85269839,
#         0.81046411]),
#  array([1.00753198, 0.99582505, 0.9659944 , ..., 0.92534609, 0.91621346,
#         0.92470031]),
#  array([1.04146606, 1.01290888, 0.97084412, ..., 0.86093854, 0.85322061,
#         0.84823073]),
#  array([1.06054516, 1.03735302, 1.01579663, ..., 0.82783771, 0.7699549 ,
#         0.76242945]),
#  array([0.95220402, 0.92852933, 0.94216944, ..., 0.71939419, 0.77730735,
#         0.860764  ]),
#  array([0.94529109, 0.94727033, 0.95123222, ..., 0.77449745, 0.77637154,
#         0.81403367]),
#  array([0.98073536, 0.96963432, 0.95834706, ..., 0.89921563, 0.90960806,
#         0.91680332]),
#  array([0.97419667, 0.96080593, 0.95863273, ..., 0.79526474, 0.76596525,
#         0.77417348]),
#  array([1.00761393, 0.96790066, 0.92100702, ..., 0.8170797 , 0.80424082,
#         0.77976254]),
#  array([1.03497478, 1.0018462 , 0.96035297, ..., 0.86911697, 0.82930234,
#         0.80361763]),
#  array([0.94827127, 0.94528249, 0.94210803, ..., 0.71827323, 0.761191  ,
#         0.83534358]),
#  array([0.93493906, 0.89638826, 0.92533848, ..., 0.50284763, 0.4791083 ,
#         0.593175  ]),
#  array([0.90767945, 0.92197014, 0.92462481, ..., 0.8936157 , 0.90313525,
#         0.94099855]),
#  array([0.93966412, 0.90110825, 0.91730982, ..., 0.80512705, 0.85504735,
#         0.89602238]),
#  array([0.9592074 , 0.95663067, 0.95363937, ..., 0.84135769, 0.88888254,
#         0.93658597]),
#  array([0.95369129, 0.97740319, 0.96729531, ..., 0.6975437 , 0.81059262,
#         0.84470125]),
#  array([0.97320737, 0.99323542, 0.99962169, ..., 0.94570788, 0.92935673,
#         0.89862336]),
#  array([1.00637875, 0.99630043, 1.00575717, ..., 0.97792141, 0.98634354,
#         1.0089199 ]),
#  [],
#  array([0.96570713, 0.96523933, 0.99415651, ..., 1.0173999 , 1.0186832 ,
#         1.0102909 ]),
#  array([0.99332741, 1.02520709, 1.05425156, ..., 0.95599672, 0.96424215,
#         0.98390313]),
#  array([1.03711736, 1.02136893, 1.0043131 , ..., 0.97755842, 0.95256521,
#         0.98609911]),
#  array([0.9912518 , 1.00571449, 1.00302685, ..., 0.97990463, 0.95943531,
#         0.91781651]),
#  array([1.02540933, 1.01092229, 1.02327857, ..., 0.98114069, 1.00941186,
#         0.96487997]),
#  array([1.07345618, 1.04119552, 1.02405196, ..., 0.93889834, 0.94267101,
#         0.94718221]),
#  array([1.01926756, 1.01259425, 1.01680051, ..., 0.99035108, 0.97004562,
#         0.86248339]),
#  array([1.08090102, 1.08405015, 0.99363055, ..., 0.95465846, 0.97595163,
#         0.90968619]),
#  array([0.97630974, 0.97043023, 0.98772664, ..., 1.00728925, 0.99078711,
#         0.95292366]),
#  array([0.99259334, 0.97693667, 0.97801963, ..., 1.01104261, 1.01038307,
#         1.00955783]),
#  array([0.965739  , 0.97146137, 0.98545392, ..., 0.99180125, 0.97640412,
#         0.95021941]),
#  array([0.95543838, 0.98493798, 0.97152565, ..., 0.96612932, 0.97878231,
#         0.97858924]),
#  array([0.97423604, 0.98577962, 0.98672651, ..., 0.96686278, 1.00140987,
#         0.96553163]),
#  array([0.94340764, 0.97393435, 0.98110397, ..., 1.0239718 , 1.00153339,
#         1.02666116]),
#  array([1.0083371 , 1.00808972, 1.00433393, ..., 1.01127643, 0.99638264,
#         1.00969703]),
#  array([1.00876267, 0.98158257, 1.00367843, ..., 0.99140813, 1.02867503,
#         1.00550947]),
#  array([0.97933354, 0.97115795, 0.96873151, ..., 1.00137892, 0.99043504,
#         0.9690254 ]),
#  array([0.98769976, 0.99138833, 1.01133117, ..., 0.93275041, 0.95690234,
#         0.9242835 ]),
#  array([1.04339111, 1.02138533, 1.01654803, ..., 1.02850589, 1.01110415,
#         1.00308662]),
#  array([1.02326737, 0.99895931, 0.98731095, ..., 0.98294345, 0.9890699 ,
#         0.99555776]),
#  array([0.99483146, 0.98923061, 0.99432705, ..., 0.98251245, 0.98004024,
#         1.00099095]),
#  array([1.02000901, 0.98953774, 0.98123193, ..., 1.01214808, 1.00826824,
#         1.0219687 ]),
#  array([0.96724787, 0.9886707 , 0.99056885, ..., 0.98109811, 0.98274322,
#         1.0185671 ]),
#  array([1.00403819, 1.00453506, 0.99822831, ..., 0.97854475, 0.96331455,
#         0.9777481 ]),
#  array([1.00083783, 1.01735369, 1.00036816, ..., 0.98785135, 0.97776841,
#         0.97464437]),
#  array([0.95231529, 0.9823896 , 0.99038715, ..., 1.02365682, 1.00975602,
#         1.00767463]),
#  array([0.97891218, 1.00515987, 1.01234513, ..., 1.00579446, 0.99477054,
#         0.98901186]),
#  array([0.98174722, 0.99114675, 0.98992663, ..., 1.01072491, 1.00316604,
#         0.99806764]),
#  array([0.94594038, 0.99972768, 0.99413429, ..., 0.99125965, 0.97489187,
#         0.96892748]),
#  array([0.98296908, 0.97798063, 0.98217721, ..., 1.00328557, 0.98930086,
#         0.9946279 ]),
#  array([1.00015195, 1.0088762 , 1.00229552, ..., 1.00192339, 0.99536197,
#         0.99048139]),
#  array([0.96997935, 0.98393999, 1.00836267, ..., 1.01509312, 0.98225439,
#         0.96222275]),
#  array([0.99163915, 1.00082528, 1.01637365, ..., 0.98435331, 0.95767107,
#         0.97426762]),
#  array([0.96100937, 0.98521587, 1.01342195, ..., 0.96400186, 0.90568998,
#         0.93949366]),
#  array([1.00126821, 1.01270547, 0.98149752, ..., 1.05707099, 1.0097396 ,
#         1.03229839]),
#  array([0.98204864, 0.95866397, 0.9964673 , ..., 1.05850329, 1.03562771,
#         1.04863053]),
#  array([0.93850372, 0.94271245, 0.96310558, ..., 0.97892842, 1.01380494,
#         1.03116665]),
#  array([1.01844387, 0.99347217, 0.99835152, ..., 1.05136598, 1.02310106,
#         1.01257759]),
#  array([1.05037248, 1.04188176, 1.01206199, ..., 0.94525562, 0.95823558,
#         0.92846639]),
#  array([1.02926345, 1.04467587, 1.03086828, ..., 0.98998306, 0.98695707,
#         0.95238695]),
#  [],
#  array([1.09226934, 1.03329044, 0.97024404, ..., 0.98242558, 1.00865659,
#         1.02873286]),
#  array([1.0276134 , 1.013199  , 1.0094209 , ..., 1.0117667 , 0.99560281,
#         0.98989257]),
#  array([1.02561736, 1.00820814, 0.99684257, ..., 0.99735243, 0.99218677,
#         0.98284921]),
#  array([1.00715816, 1.0188146 , 0.99781045, ..., 0.98212864, 0.97226824,
#         0.93910443]),
#  array([1.01016238, 0.99391785, 1.00743883, ..., 0.98811359, 0.95860195,
#         0.96850365]),
#  array([1.06135376, 1.03952219, 1.01528321, ..., 0.93110565, 0.9692962 ,
#         0.97467052]),
#  array([0.94300033, 0.94956304, 0.96411379, ..., 0.92844888, 0.93225365,
#         0.88911437]),
#  array([1.00063322, 0.97010894, 0.97532119, ..., 0.91259241, 0.9602091 ,
#         0.98577321]),
#  array([1.07891486, 1.03412731, 1.00424309, ..., 0.9907361 , 0.9437131 ,
#         0.93733458]),
#  [],
#  array([1.05804438, 1.01613258, 1.0015705 , ..., 0.973238  , 0.98064037,
#         0.98377137]),
#  array([1.01253003, 0.98720197, 0.98348114, ..., 0.957184  , 0.93725702,
#         0.98112545]),
#  array([0.97063458, 1.01726096, 1.02258358, ..., 1.0207483 , 0.99818061,
#         1.01784981]),
#  array([0.98953363, 0.97248922, 0.97483174, ..., 0.97050045, 0.95828627,
#         0.98585365]),
#  array([1.09464388, 1.05052248, 1.03411675, ..., 0.97874717, 0.96521223,
#         0.93722841]),
#  array([1.00828428, 0.99328951, 0.9977913 , ..., 0.99166848, 0.99238435,
#         0.98024138]),
#  array([0.99445229, 1.02995699, 1.03974277, ..., 0.94717627, 0.95135893,
#         1.02708091]),
#  array([1.01458189, 1.00244502, 1.01723357, ..., 0.98923188, 1.06400966,
#         1.00651606]),
#  array([1.01530206, 1.03949058, 1.02086425, ..., 0.97767447, 0.91885799,
#         0.88783077]),
#  array([1.04336592, 1.02410274, 1.04702426, ..., 0.91990386, 0.97908933,
#         0.97837638]),
#  array([0.98318913, 0.99003332, 0.99977097, ..., 0.99378423, 0.97784614,
#         0.99756723]),
#  array([1.02913433, 1.02823309, 1.01203019, ..., 1.0339886 , 1.02403819,
#         1.03673083]),
#  array([0.99427102, 1.01552648, 0.99927207, ..., 0.97827653, 0.95682408,
#         0.93437154]),
#  array([1.01797468, 0.99757892, 0.99394184, ..., 0.97267839, 0.95397846,
#         0.96203749]),
#  array([0.98435741, 1.00360947, 0.99052758, ..., 0.97183164, 0.98420569,
#         0.99807613]),
#  array([0.97385967, 0.9795676 , 0.98244627, ..., 0.96805245, 0.97503817,
#         1.01781878]),
#  array([0.95592015, 0.99295814, 0.98801485, ..., 1.00563501, 0.99958656,
#         1.01165611]),
#  array([1.01585934, 0.9703023 , 0.93510389, ..., 1.0382264 , 1.06854291,
#         1.06528952]),
#  array([0.99217571, 0.99729815, 1.01579226, ..., 1.00698861, 1.01439681,
#         1.0201214 ]),
#  array([1.00447942, 0.98483111, 0.99831287, ..., 0.98250343, 0.99718555,
#         1.01715808]),
#  array([0.96583374, 1.00010124, 1.01170778, ..., 1.04471049, 1.08952859,
#         1.09560951]),
#  [],
#  array([1.00302248, 1.000455  , 0.99857465, ..., 1.0662414 , 1.04446021,
#         1.04347027]),
#  array([1.01506227, 1.0041252 , 0.98130289, ..., 1.03692015, 1.06733206,
#         1.09708669]),
#  array([0.98205324, 0.99398457, 1.00352912, ..., 1.04460885, 1.08657737,
#         1.15772909]),
#  array([0.98845868, 0.9932009 , 1.01168315, ..., 1.04259037, 1.05525764,
#         1.0834616 ]),
#  array([1.00271981, 0.99817734, 0.99638615, ..., 1.02877171, 1.01615017,
#         1.02870436]),
#  array([0.98356987, 1.01035278, 1.01572067, ..., 1.14642209, 1.15470683,
#         1.14322682]),
#  array([0.97243311, 1.01870021, 1.0162402 , ..., 1.03259963, 0.97878989,
#         1.02813871]),
#  array([0.97118386, 0.97254296, 0.97156615, ..., 1.00615751, 1.00240999,
#         0.99292394]),
#  array([0.98279172, 1.01721716, 1.02547739, ..., 0.96764229, 0.97633974,
#         0.9879253 ]),
#  array([0.98526341, 0.98406871, 0.99242252, ..., 0.99014103, 0.97775485,
#         0.98291001]),
#  array([1.00196212, 1.01278236, 1.01005054, ..., 0.97605994, 0.9697024 ,
#         0.98100646]),
#  array([1.02567244, 0.97935247, 1.00413955, ..., 1.00982767, 0.99306358,
#         0.97062854]),
#  array([0.99536659, 0.96815282, 0.97823452, ..., 0.94745882, 0.91744372,
#         0.90323606]),
#  array([1.00354303, 0.97622453, 0.99127803, ..., 0.98246434, 0.97191195,
#         0.9920547 ]),
#  array([1.10702337, 1.06587333, 1.02980373, ..., 1.12813693, 1.17925309,
#         1.21645549]),
#  array([1.02839724, 1.03412019, 1.03669615, ..., 1.09387033, 1.07548301,
#         1.01513162]),
#  array([1.03303351, 1.02724881, 1.02299261, ..., 0.98986207, 0.9977009 ,
#         0.99745111]),
#  array([1.01166236, 1.01232036, 1.01441604, ..., 1.00215008, 1.00374855,
#         1.00890933]),
#  array([0.97988213, 0.98468311, 0.99913443, ..., 0.98146254, 0.9805875 ,
#         0.96129603]),
#  array([1.37957004, 1.3746464 , 1.38189162, ..., 1.12965238, 1.11727999,
#         1.1007474 ]),
#  array([0.99937418, 0.99219755, 0.9977297 , ..., 1.01174517, 1.01374046,
#         1.00711277]),
#  array([1.11288871, 1.11457107, 1.13161934, ..., 1.0534446 , 0.99729235,
#         0.97159668]),
#  array([0.94639813, 0.98386261, 1.00859467, ..., 0.95849257, 0.93964389,
#         0.98474277]),
#  array([1.00531646, 1.04036056, 1.03019863, ..., 0.92595965, 0.96028947,
#         0.981152  ]),
#  array([1.00738924, 1.01278882, 1.01174626, ..., 0.9868316 , 0.99728345,
#         0.97549908]),
#  array([1.03511363, 0.98766288, 0.99735261, ..., 0.99615586, 0.95626614,
#         0.9387161 ]),
#  array([0.75797969, 0.72474062, 0.72126785, ..., 0.97112455, 0.98237382,
#         1.00153829]),
#  [],
#  [],
#  array([1.01932871, 1.01067933, 1.00607601, ..., 0.97871172, 0.96489804,
#         0.94108228]),
#  array([1.01635968, 1.00585792, 1.00492115, ..., 0.94763551, 0.92833618,
#         0.94619318]),
#  array([1.01908218, 1.01736208, 1.00411627, ..., 1.0203524 , 1.01866809,
#         1.00256779]),
#  array([0.98234721, 0.98830485, 0.97785501, ..., 0.97344743, 0.98085753,
#         0.98519943]),
#  array([0.98929169, 0.98205742, 1.00817525, ..., 0.94066715, 0.91503438,
#         0.91830366]),
#  array([1.04992557, 1.04426683, 1.03707802, ..., 0.99172907, 0.99106802,
#         1.02353156]),
#  array([0.97055535, 0.99520915, 0.9909958 , ..., 0.99039483, 0.98781918,
#         0.98364406]),
#  array([1.02413758, 1.00805556, 0.9937468 , ..., 0.97489793, 0.95182344,
#         0.98200112]),
#  array([1.08125077, 1.06418665, 1.04443182, ..., 0.99900484, 1.00365334,
#         1.021096  ]),
#  array([0.98967156, 0.99730969, 1.00121905, ..., 0.99722547, 0.98274707,
#         0.99487354]),
#  array([0.9950672 , 0.9996231 , 1.01581389, ..., 1.00908702, 1.01689227,
#         1.00312291]),
#  array([1.00571651, 1.0130253 , 1.02210527, ..., 0.89735   , 0.92020414,
#         0.91076535]),
#  array([1.00482141, 0.99228434, 0.99145444, ..., 0.97663629, 0.97135493,
#         0.96555775]),
#  array([1.03450835, 1.039735  , 1.03145474, ..., 0.95109642, 0.93722622,
#         0.94792466]),
#  [],
#  array([0.92460851, 0.93348079, 0.94295397, ..., 0.84112173, 0.85436376,
#         0.86651796]),
#  array([0.98419638, 0.98561132, 0.9750041 , ..., 0.9926689 , 0.99056595,
#         1.01690882]),
#  array([1.00158778, 0.9886036 , 0.98260838, ..., 0.94172881, 0.93374077,
#         0.97164262]),
#  array([0.99442203, 0.99260082, 0.99042809, ..., 1.01607604, 0.97787271,
#         0.97097192]),
#  array([0.99472443, 0.98162715, 0.98417059, ..., 0.98260446, 0.98200509,
#         0.99015001]),
#  array([0.99731612, 0.98464742, 1.00672827, ..., 0.980049  , 0.98612207,
#         0.99715277]),
#  array([0.99113273, 0.98249726, 0.99165744, ..., 0.96620984, 0.93487626,
#         0.99891866]),
#  array([0.96461679, 0.95579226, 0.97853433, ..., 0.98337862, 1.01949183,
#         1.01078352]),
#  array([1.03578371, 1.03141692, 0.99610277, ..., 1.03340655, 1.02034461,
#         0.9603496 ]),
#  array([1.02868713, 1.02404117, 1.02676226, ..., 0.9530089 , 0.94854289,
#         0.94456796]),
#  array([0.98260444, 1.00365595, 1.00421742, ..., 0.97615138, 1.01088197,
#         1.04744394]),
#  array([0.98287607, 1.01011074, 1.00928218, ..., 1.03351758, 1.00900641,
#         0.97777323]),
#  array([1.03758706, 1.00742555, 1.01217618, ..., 0.99152201, 0.98276789,
#         0.92542036]),
#  array([1.00117605, 1.01928918, 1.02421521, ..., 0.97305695, 1.01156261,
#         0.99548783]),
#  array([1.01961586, 1.00672398, 0.99111131, ..., 0.99568306, 0.98841228,
#         0.97484629]),
#  array([0.993008  , 0.97905618, 0.9640531 , ..., 1.00001852, 1.00239058,
#         1.01379061]),
#  array([1.01509365, 1.02984346, 1.02356771, ..., 1.07817053, 1.08266094,
#         1.06624511]),
#  array([0.97524333, 0.98474335, 0.9998744 , ..., 0.9887493 , 0.99623098,
#         0.96747043]),
#  array([1.04188314, 1.05072532, 1.01899605, ..., 0.97333786, 0.95333498,
#         0.96600534]),
#  array([0.99725798, 0.98952575, 0.9890496 , ..., 0.96865093, 0.9510999 ,
#         0.9935833 ]),
#  array([1.01751753, 1.02884921, 1.02544566, ..., 0.97540454, 0.95721678,
#         0.94388821]),
#  array([1.03576259, 1.02546013, 1.00299061, ..., 0.96217455, 1.00237689,
#         1.00987692]),
#  array([0.9926237 , 0.9737032 , 0.99089826, ..., 0.9714974 , 1.01008857,
#         0.96254388]),
#  [],
#  [],
#  array([1.01345642, 0.99305424, 0.97598673, ..., 0.97111194, 0.96159337,
#         0.96952306]),
#  [],
#  array([0.9345907 , 0.97114379, 0.97426142, ..., 1.11825873, 1.13064539,
#         1.13573295]),
#  array([1.04460237, 1.02116868, 1.0326067 , ..., 0.9378621 , 1.0454166 ,
#         1.18735519]),
#  array([1.06860505, 1.04879341, 1.02942742, ..., 0.96973049, 0.94346212,
#         0.92204045]),
#  array([1.00955851, 1.02282084, 1.00871256, ..., 0.97749249, 1.00629715,
#         1.00775051]),
#  array([1.13204595, 1.05990505, 0.99516673, ..., 0.99594826, 1.0267368 ,
#         1.03716532]),
#  array([1.03729513, 1.00389577, 1.0283735 , ..., 0.98389373, 0.94211301,
#         0.92501289]),
#  array([1.04155373, 1.05204791, 1.04219499, ..., 1.01506409, 0.99602478,
#         0.98067991]),
#  array([1.01025089, 1.00226711, 1.00542638, ..., 0.96555561, 0.96277652,
#         0.98444387]),
#  array([0.97160333, 0.9378597 , 0.91437102, ..., 1.08851786, 1.15030504,
#         1.28040546]),
#  array([0.8275014 , 0.87133343, 0.91945096, ..., 0.97873457, 0.96708624,
#         0.97786937]),
#  array([0.93159316, 0.95634337, 0.93911321, ..., 0.95620713, 0.95942609,
#         0.96657014]),
#  array([1.06777674, 1.06265375, 1.04573356, ..., 1.034415  , 1.15871032,
#         1.14384335]),
#  array([0.99336223, 0.98688111, 0.97229746, ..., 0.97607968, 1.01076365,
#         0.96491213]),
#  array([0.99979725, 0.99858148, 1.00186949, ..., 0.99997108, 0.99520351,
#         0.99561425]),
#  array([0.99958306, 1.00223796, 1.00129219, ..., 0.9956374 , 0.99196387,
#         0.99271494]),
#  array([0.99512048, 0.99419512, 0.99031974, ..., 0.99584078, 0.99744347,
#         0.99081936]),
#  array([1.00710296, 1.0026021 , 1.0007312 , ..., 0.99775203, 0.99933867,
#         0.99614641]),
#  array([0.95076106, 0.95939112, 0.96925094, ..., 1.01309376, 1.00902959,
#         0.97421069]),
#  array([0.9615484 , 0.97921027, 0.96787144, ..., 1.05890306, 1.03468535,
#         1.0369018 ]),
#  array([0.93478172, 0.929675  , 0.93360369, ..., 1.04599884, 1.04494189,
#         0.99899343]),
#  array([0.92994606, 0.96340608, 0.97268525, ..., 1.0411734 , 1.00332798,
#         0.98992373]),
#  array([0.97737209, 1.02070882, 1.01850167, ..., 1.03204123, 1.0403878 ,
#         0.9931164 ]),
#  array([0.98359057, 0.98020338, 0.94222883, ..., 1.46415657, 1.57777137,
#         1.63360166]),
#  array([0.92642764, 0.91846002, 0.93893243, ..., 1.29583485, 1.61967303,
#         1.57454955]),
#  array([0.51468051, 0.51711312, 0.53076056, ..., 0.89664727, 0.96509549,
#         0.89172192]),
#  array([0.88523397, 0.86488653, 0.8971261 , ..., 0.9755777 , 0.97444084,
#         0.95764052]),
#  array([0.98999228, 0.99457216, 1.01263291, ..., 0.92632499, 0.90113813,
#         0.92205012]),
#  array([1.01335581, 1.02884279, 1.0289319 , ..., 0.98896449, 1.00450577,
#         0.9714853 ]),
#  array([0.99430347, 0.9521842 , 0.95573992, ..., 0.9843157 , 1.01169708,
#         0.89980075]),
#  array([1.00212527, 1.01050851, 1.01740725, ..., 0.94037191, 0.94702095,
#         0.95886963]),
#  array([0.99635037, 0.99107502, 0.98530845, ..., 0.99634251, 0.98819634,
#         0.98748181]),
#  array([0.95001229, 0.93905022, 0.93201765, ..., 0.99168062, 1.00454309,
#         0.9779522 ]),
#  array([0.98561765, 1.00366422, 0.99139651, ..., 0.94246089, 0.95453665,
#         0.92863639]),
#  array([0.99694595, 1.00064974, 0.99705923, ..., 0.99912624, 0.99127591,
#         1.01333086]),
#  array([1.01171489, 1.00316621, 1.008767  , ..., 0.99574392, 0.99102871,
#         0.99566629]),
#  array([0.98837902, 1.00026656, 0.9932749 , ..., 1.01879248, 0.98665695,
#         1.01318908]),
#  array([1.09736367, 1.07567946, 1.05154077, ..., 1.0266093 , 1.02175274,
#         0.9988587 ]),
#  array([1.01035528, 0.9938054 , 0.99791977, ..., 0.98546686, 0.99113512,
#         0.93123885]),
#  array([1.01807708, 1.03212029, 1.04854421, ..., 0.98335871, 0.98003633,
#         0.97181099]),
#  array([0.96877516, 0.98295685, 1.01023191, ..., 1.00096766, 0.98351046,
#         0.99960732]),
#  array([0.96612033, 0.98715736, 1.00083089, ..., 0.98301936, 0.98265442,
#         0.91123648]),
#  array([1.01925521, 1.00011263, 1.01090584, ..., 0.99855924, 0.99157742,
#         1.0209147 ]),
#  array([0.98178801, 0.99458556, 0.99722002, ..., 0.98549512, 0.97518772,
#         0.97864053]),
#  array([0.95636647, 0.96739081, 0.97022   , ..., 0.99698333, 1.01249812,
#         1.01306929]),
#  array([1.01005497, 0.99914456, 0.99268224, ..., 0.9756232 , 0.9688303 ,
#         0.97865343]),
#  array([0.95120826, 0.97775881, 0.98433381, ..., 1.24265034, 1.24588074,
#         1.26289358]),
#  array([0.99569644, 1.00809373, 1.02256524, ..., 1.06526258, 1.1160226 ,
#         1.14706379]),
#  array([0.94292402, 0.98524868, 0.97006012, ..., 1.00558923, 1.04990502,
#         1.00647443]),
#  [],
#  array([0.89987877, 0.91855809, 0.92541289, ..., 0.95791998, 0.94799026,
#         0.92031501]),
#  array([0.95660302, 0.98464022, 1.01993722, ..., 0.99600387, 0.99608409,
#         1.03428237]),
#  array([1.04618893, 0.9515043 , 0.93616401, ..., 1.05600652, 0.95970233,
#         0.82450969]),
#  array([1.00431341, 1.00346485, 1.00337725, ..., 0.99514449, 1.00448275,
#         0.97553823]),
#  array([1.02646794, 1.01439827, 1.02192533, ..., 1.02358426, 1.02979619,
#         1.03049172]),
#  array([0.98016064, 0.99604777, 0.98672399, ..., 1.00617062, 1.03250084,
#         1.0316345 ]),
#  array([0.98892035, 0.98668057, 0.99120109, ..., 1.02487714, 1.0248375 ,
#         1.01557901]),
#  array([0.99737956, 0.99840334, 0.99747749, ..., 1.01863649, 1.01658257,
#         1.01557543]),
#  array([0.98991348, 0.99462628, 0.98240266, ..., 1.02382906, 0.95384606,
#         0.82721546]),
#  array([0.97339187, 0.98104618, 0.99563532, ..., 1.01948555, 0.99468216,
#         0.96277372]),
#  array([0.95586335, 0.99809607, 1.00527315, ..., 1.00921785, 1.02470564,
#         1.02881612]),
#  array([0.95786911, 0.97439925, 0.97866327, ..., 0.98187405, 0.99120217,
#         0.98268419]),
#  array([0.95899561, 0.97026533, 0.97426225, ..., 1.00340384, 1.01517944,
#         1.01475147]),
#  array([1.06097943, 1.06746508, 1.07235158, ..., 1.02853078, 1.01087615,
#         1.00946261]),
#  array([1.00503998, 0.98233146, 0.99560921, ..., 1.07012796, 1.07193501,
#         1.05101509]),
#  array([1.04387955, 1.02903647, 0.95090763, ..., 0.86792999, 0.90256022,
#         0.83861522]),
#  array([0.9935713 , 0.96266881, 0.96755032, ..., 1.04927539, 1.0271178 ,
#         0.99132851]),
#  [],
#  array([0.98240823, 0.98189425, 0.98326476, ..., 0.96210787, 0.95708304,
#         0.95736641]),
#  array([0.93757343, 0.95591093, 0.98454607, ..., 1.00874102, 0.99105817,
#         1.00520104]),
#  [],
#  array([0.77478424, 0.7099393 , 0.67230279, ..., 0.98756705, 0.99753866,
#         0.99759869]),
#  array([0.97744039, 1.00340602, 0.97978744, ..., 0.97132061, 0.99021845,
#         0.96788339]),
#  array([1.00598627, 0.99745591, 0.99322131, ..., 1.01853867, 1.00938805,
#         0.98968592]),
#  array([0.98977838, 0.99284387, 0.99124407, ..., 0.99392775, 0.98476015,
#         1.00969434]),
#  array([1.0112677 , 1.01142362, 1.00018186, ..., 0.98984832, 0.97991452,
#         0.99440798]),
#  array([0.99050402, 0.98273106, 0.9828523 , ..., 0.99490722, 0.98678374,
#         1.00491475]),
#  array([0.97544299, 1.00886854, 1.01021682, ..., 1.01298197, 1.01210173,
#         1.01372862]),
#  array([1.01064432, 0.99115208, 0.97873226, ..., 1.02463636, 1.05895603,
#         0.99957888]),
#  array([0.99610441, 0.9948959 , 0.99754417, ..., 0.989999  , 1.00005379,
#         1.00534205]),
#  array([0.98153999, 0.98692582, 0.99699912, ..., 1.05008708, 1.03708686,
#         1.06110116]),
#  array([1.05566425, 1.04926677, 1.04053349, ..., 0.9892509 , 0.95334883,
#         0.9326053 ]),
#  array([0.93203676, 0.93786116, 0.93930285, ..., 1.00798297, 1.02422027,
#         1.02649774]),
#  array([1.02567736, 1.01313461, 1.01273974, ..., 1.01104228, 0.99395133,
#         0.97747242]),
#  array([0.97161652, 0.97540117, 0.98268716, ..., 0.97620385, 0.99886007,
#         0.99661371]),
#  array([1.07502858, 1.07396251, 1.04262143, ..., 1.00478509, 1.01160589,
#         0.98792301]),
#  array([0.99539917, 1.00316498, 1.00939259, ..., 0.98743869, 0.9834298 ,
#         0.98656142]),
#  array([0.9815933 , 0.96933182, 0.99285783, ..., 0.96489864, 0.95630662,
#         0.98480972]),
#  array([0.96045814, 0.97748114, 0.99283132, ..., 0.909118  , 0.87456557,
#         0.86492758]),
#  array([0.99085839, 0.99808704, 0.99997757, ..., 0.96854679, 0.96979638,
#         0.97713884]),
#  array([0.98691776, 0.98103639, 0.98777012, ..., 0.99545421, 0.97317767,
#         0.96782996]),
#  [],
#  array([0.99861904, 1.01027489, 1.00604   , ..., 1.00793612, 0.9961464 ,
#         0.99509031]),
#  array([1.01505498, 0.95743046, 0.93384648, ..., 0.98066686, 0.94046655,
#         0.83692235]),
#  array([1.02329552, 0.95487827, 0.98468817, ..., 0.87124275, 0.82576862,
#         0.93796187]),
#  array([0.9984134 , 1.00066045, 1.00623996, ..., 1.01454892, 0.98697421,
#         0.97349552]),
#  array([1.0202527 , 0.9913201 , 0.98738195, ..., 0.98522885, 0.97483587,
#         0.93448609]),
#  array([0.98583   , 0.99108506, 0.96164972, ..., 0.93866547, 1.01003059,
#         1.07984573]),
#  array([0.94710029, 0.97285957, 0.99672869, ..., 1.10680489, 1.08711496,
#         1.07836201]),
#  array([1.02902165, 1.03934683, 1.01309025, ..., 1.00084718, 0.99029553,
#         0.99258354]),
#  array([1.01461456, 0.9999931 , 0.99167517, ..., 0.99458159, 1.01342737,
#         0.99055109]),
#  array([0.98638685, 0.97310142, 1.00361124, ..., 0.99177644, 0.98772857,
#         0.98600595]),
#  array([0.97835417, 0.97864348, 0.99083542, ..., 0.98134491, 0.9665513 ,
#         0.94219826]),
#  array([1.01640665, 1.01704205, 1.0164749 , ..., 1.0785903 , 1.05957128,
#         1.00043706]),
#  array([1.00717231, 0.9854532 , 0.97867141, ..., 1.04848271, 1.02711551,
#         1.0521963 ]),
#  array([0.95706094, 0.97310427, 0.98211322, ..., 0.93955165, 0.92972355,
#         0.92977729]),
#  array([0.99330258, 0.99844954, 0.99895374, ..., 1.01069305, 0.99509882,
#         0.98564369]),
#  array([0.99901873, 1.01931896, 1.00626827, ..., 1.0470877 , 1.03425076,
#         1.02556652]),
#  array([1.02526436, 1.03418614, 1.03253139, ..., 1.10585867, 1.09054024,
#         1.10270421]),
#  array([0.98964326, 1.01646444, 1.04261919, ..., 0.99485565, 0.98567297,
#         0.98409194]),
#  array([0.98255069, 0.99923222, 0.99725305, ..., 0.99604394, 1.03113978,
#         1.00660845]),
#  [],
#  array([1.06595295, 1.05047653, 1.05857106, ..., 1.06054952, 1.03691393,
#         0.98320073]),
#  array([0.97602716, 0.9942569 , 1.00789317, ..., 0.99664853, 0.99665615,
#         0.96798858]),
#  array([0.99174922, 0.99609495, 0.98197732, ..., 0.98326071, 0.95244581,
#         0.93525767]),
#  array([1.02595088, 0.99520434, 0.99512227, ..., 0.88411037, 0.91418617,
#         0.97015765]),
#  array([1.01826122, 1.01256663, 1.00492978, ..., 0.99315996, 0.97081196,
#         0.935777  ]),
#  array([1.00213913, 1.02286706, 1.01376203, ..., 0.98018754, 0.96988818,
#         0.95992257]),
#  array([0.98341308, 0.9738264 , 0.98432144, ..., 0.99866045, 1.00217083,
#         0.98128348]),
#  array([1.00801017, 1.00479614, 1.00197877, ..., 0.97328605, 0.9727366 ,
#         0.97207995]),
#  array([0.97038689, 0.97046671, 0.96414757, ..., 0.94023885, 0.91956654,
#         0.8928807 ]),
#  array([0.97419049, 0.99938485, 1.00988045, ..., 0.96595428, 0.98501263,
#         1.00855981]),
#  array([1.0073155 , 1.01652902, 1.00229761, ..., 0.99401319, 0.96228029,
#         0.98787627]),
#  array([0.99825637, 1.0152804 , 1.01253659, ..., 0.95020432, 0.99680571,
#         0.95417976]),
#  array([0.99681275, 1.01109112, 0.99437486, ..., 1.00719202, 0.97597519,
#         0.96588907]),
#  array([1.02296419, 1.04529788, 1.03608179, ..., 1.01940153, 0.96392626,
#         0.98200426]),
#  array([0.98541663, 0.98909379, 1.00906403, ..., 0.88204964, 0.92576327,
#         0.93703973]),
#  array([0.99600472, 1.0213868 , 1.0071095 , ..., 0.99416988, 1.01437964,
#         0.99636809]),
#  array([0.9562212 , 0.98257663, 0.99487398, ..., 1.00511783, 0.99907933,
#         1.00234418]),
#  array([0.99014245, 1.04953277, 1.08138342, ..., 0.90324321, 0.93175681,
#         0.73750879]),
#  array([0.98732193, 0.98603991, 1.01077923, ..., 0.84660181, 0.77089414,
#         0.7728379 ]),
#  array([0.98291816, 0.98679006, 0.99828471, ..., 0.99491718, 1.02604012,
#         1.04483863]),
#  array([0.92781978, 0.93753254, 0.94460611, ..., 1.05522364, 1.00120565,
#         1.02294482]),
#  array([0.99627599, 0.98847202, 0.99613347, ..., 0.91327893, 0.86131527,
#         0.85058982]),
#  array([0.98571895, 0.99590208, 0.99137026, ..., 0.9762609 , 0.93248783,
#         0.92498381]),
#  array([0.96449076, 0.98605119, 1.01997133, ..., 0.90546687, 0.90149494,
#         0.9002403 ]),
#  array([0.97691219, 0.97020688, 0.97885152, ..., 0.64572156, 0.73856277,
#         0.87414718]),
#  array([0.94209381, 0.97708207, 0.97300196, ..., 0.80177219, 0.7523114 ,
#         0.62257108]),
#  array([0.70246505, 0.68169686, 0.67819189, ..., 0.98764661, 0.98650877,
#         1.03012852]),
#  array([0.97967201, 0.99035203, 1.00027289, ..., 0.9997937 , 1.00367139,
#         0.99060918]),
#  array([0.99582732, 0.99597363, 1.0004224 , ..., 0.9907708 , 0.98978961,
#         0.93876154]),
#  array([0.96465714, 0.95854818, 0.98248161, ..., 1.00339998, 1.00011854,
#         1.00155237]),
#  array([0.99720395, 0.99903388, 0.99820107, ..., 0.95099349, 1.00631596,
#         0.98856062]),
#  array([1.16326822, 1.14231709, 1.11654015, ..., 0.96856096, 1.01263833,
#         1.06007519]),
#  array([0.98288306, 0.99012478, 1.00353893, ..., 1.17617095, 1.21394284,
#         1.3376875 ]),
#  array([1.00433573, 0.99868336, 0.9994712 , ..., 0.99769886, 1.00789405,
#         1.02672112]),
#  array([0.9981547 , 0.98060504, 0.96051215, ..., 0.87839258, 0.87701632,
#         0.89008407]),
#  array([1.12110438, 1.13961993, 1.15153692, ..., 0.97319668, 0.97291737,
#         0.99518018]),
#  array([1.03072881, 0.99412627, 0.9848573 , ..., 0.95324866, 0.9475288 ,
#         0.95365872]),
#  array([1.04536476, 1.06552201, 1.08515337, ..., 1.02879465, 1.03899502,
#         0.94636828]),
#  array([0.99082486, 0.99617018, 0.98996121, ..., 1.00352175, 1.03593022,
#         1.05422763]),
#  [],
#  array([0.97536162, 0.99665999, 1.0040014 , ..., 0.99825757, 1.00802706,
#         1.02018807]),
#  array([0.98376406, 0.99044083, 1.00376862, ..., 1.00388745, 0.99115466,
#         0.97666224]),
#  [],
#  array([0.95833301, 0.95395474, 0.96257127, ..., 0.9904989 , 0.99673808,
#         0.99729859]),
#  array([1.03098465, 1.03740145, 1.06360001, ..., 0.99343689, 0.96112879,
#         0.98023648]),
#  array([1.00775428, 1.00879805, 1.01440056, ..., 0.98719004, 0.9845018 ,
#         0.98421158]),
#  array([1.04071315, 1.03910337, 1.02785414, ..., 0.98323374, 1.01366824,
#         1.01706608]),
#  array([1.09987557, 1.10500932, 1.11037446, ..., 1.05068857, 1.0398603 ,
#         1.02967274]),
#  array([1.01088011, 1.00230025, 1.00943125, ..., 1.02260965, 0.97556776,
#         0.98048977]),
#  array([0.9958124 , 0.99164812, 0.99511886, ..., 0.99370969, 0.99550671,
#         0.99873315]),
#  array([1.30445969, 1.26374819, 1.21792802, ..., 1.03479332, 1.03822115,
#         1.02548722]),
#  array([1.23671259, 1.20330071, 1.16786502, ..., 0.99492971, 0.95820676,
#         0.96876828]),
#  array([0.95326205, 0.96658523, 0.97395063, ..., 1.02864623, 1.04002105,
#         1.00517375]),
#  array([1.05939233, 1.0624136 , 1.0579503 , ..., 1.14029565, 1.14907196,
#         1.14625356]),
#  array([0.98922268, 1.00018221, 1.01045263, ..., 0.97885885, 0.94767503,
#         0.95649743]),
#  array([0.90449797, 0.85738502, 0.7954929 , ..., 0.95146532, 0.98741732,
#         1.03691239]),
#  array([0.94050373, 0.97158475, 0.97202163, ..., 0.97003597, 0.94857819,
#         0.94831677]),
#  array([0.96253793, 0.9535709 , 0.94596143, ..., 0.96716961, 0.97984297,
#         0.94329415]),
#  array([0.99117814, 1.01335513, 1.02218237, ..., 1.06151027, 0.98731901,
#         0.98317507]),
#  array([0.92180308, 0.94434555, 0.98454752, ..., 0.97255509, 1.00865972,
#         0.99330429]),
#  [],
#  array([1.01089418, 0.99459519, 0.98520409, ..., 0.99427882, 0.9974532 ,
#         0.99646946]),
#  array([0.99657437, 1.00134127, 1.0020074 , ..., 1.01187219, 0.99620909,
#         1.01103449]),
#  array([1.0072621 , 1.00935647, 1.00640789, ..., 1.0114017 , 0.99410513,
#         0.99074032]),
#  array([1.00595309, 1.02118793, 1.01066426, ..., 0.99485572, 0.98863078,
#         1.00200856]),
#  array([1.00152255, 0.99886919, 0.9938516 , ..., 0.99251342, 0.99190865,
#         0.97739492]),
#  array([1.00124824, 0.98335505, 1.00132872, ..., 1.01528513, 0.98600067,
#         0.97416131]),
#  array([0.83447074, 0.82288752, 0.83196235, ..., 0.9956185 , 0.97917038,
#         0.90563771]),
#  array([1.02295551, 0.99751376, 0.98042   , ..., 1.022968  , 0.99137514,
#         0.9747888 ]),
#  [],
#  array([1.01668591, 1.03753997, 1.03876789, ..., 0.94908997, 0.89608739,
#         0.83533845]),
#  array([1.03955129, 1.04677942, 1.03888714, ..., 1.15636411, 1.13367789,
#         1.08034736]),
#  array([1.03242273, 1.02555585, 1.02827565, ..., 0.97703461, 0.97043881,
#         0.96315457]),
#  array([0.97009183, 0.9646641 , 0.94533983, ..., 1.02360228, 1.04001052,
#         1.05671586]),
#  array([1.00321893, 0.99564946, 0.98518351, ..., 1.0133881 , 1.02081932,
#         1.03900943]),
#  [],
#  array([1.01879468, 1.01820218, 1.00482277, ..., 1.02509361, 1.0375991 ,
#         1.06753794]),
#  array([0.97723682, 0.97059695, 0.9760844 , ..., 1.03642845, 1.02648991,
#         1.03485374]),
#  array([0.96167451, 0.94125131, 0.94110869, ..., 0.97956354, 0.98957115,
#         0.99499072]),
#  array([0.98829931, 0.98401441, 0.99010059, ..., 1.00384701, 0.99293118,
#         1.01029342]),
#  array([0.96059239, 0.94093681, 0.93521747, ..., 0.99987586, 1.01273501,
#         0.99527284]),
#  array([0.97071721, 0.95573329, 0.95394441, ..., 0.99960093, 1.01418618,
#         0.98286391]),
#  array([0.97371863, 0.94770216, 0.96561445, ..., 1.09640752, 1.11154326,
#         1.119665  ]),
#  array([1.01766317, 1.00590543, 0.99279083, ..., 0.99177622, 0.97008627,
#         0.99524544]),
#  array([1.04876159, 1.02241901, 1.01650338, ..., 1.08878007, 1.09709227,
#         1.08647297]),
#  array([1.01351699, 1.01734365, 1.01558779, ..., 1.0016014 , 0.99713   ,
#         0.9918463 ]),
#  array([1.02784672, 1.04002508, 1.04836543, ..., 1.00405146, 0.98816898,
#         0.95548327]),
#  array([0.9858124 , 0.98869413, 0.99162858, ..., 0.99042699, 0.99258935,
#         1.0055321 ]),
#  array([0.72753215, 0.71696746, 0.74623364, ..., 0.91819509, 0.93432637,
#         0.94567775]),
#  array([1.10645741, 1.05439541, 1.03833591, ..., 1.05592773, 1.07476672,
#         1.0699233 ]),
#  array([0.95268775, 0.99168712, 0.98478043, ..., 1.04323961, 1.08916302,
#         1.09407931]),
#  array([0.97038559, 0.97435876, 0.96362747, ..., 0.97495783, 0.91504497,
#         0.93280708]),
#  array([1.00338933, 1.01475977, 1.01532802, ..., 1.00878796, 1.03242261,
#         1.04487776]),
#  array([1.00388658, 0.97120328, 1.04178449, ..., 0.98784922, 0.99439601,
#         1.01060062]),
#  array([0.95047616, 0.98881136, 1.00518852, ..., 1.01874951, 1.02536289,
#         0.95523075]),
#  array([0.97281722, 0.99530797, 1.00527889, ..., 1.03720681, 1.0286242 ,
#         0.95793953]),
#  array([0.99918298, 0.99751441, 0.99152696, ..., 1.03428195, 0.99102869,
#         0.99854402]),
# ...
#  array([0.96475303, 0.92483179, 0.87390795, ..., 0.99098896, 0.97860569,
#         0.98089153]),
#  array([1.05133499, 1.05673383, 1.04491743, ..., 1.01259436, 1.01271632,
#         1.00434118]),
#  array([1.00268635, 0.99044834, 0.96429441, ..., 0.88997399, 0.90377604,
#         0.9016493 ]),
#  array([1.00678522, 1.00006541, 0.99924044, ..., 0.91021746, 0.89868539,
#         0.88893457]),
#  array([1.32095094, 1.11969243, 1.05068115, ..., 1.01462856, 0.97020882,
#         0.96439813]),
#  array([1.04612125, 1.03004821, 1.00907732, ..., 0.96516081, 0.96711506,
#         0.98586213]),
#  array([0.97892604, 0.97756484, 0.9791131 , ..., 1.00027582, 0.99418676,
#         0.98624347]),
#  array([0.9998066 , 1.01344803, 1.03310247, ..., 1.04518098, 1.01699841,
#         1.01734351]),
#  array([1.00931276, 1.01232938, 1.02665754, ..., 1.00307281, 1.01058227,
#         0.99250081]),
#  array([0.97657278, 1.00671191, 0.98467582, ..., 1.02295568, 0.98267324,
#         0.94698508]),
#  array([1.02577837, 1.02602468, 1.02782192, ..., 1.06857771, 1.06147589,
#         1.09946556]),
#  array([0.98758697, 0.97688096, 0.95959903, ..., 0.91982824, 0.94400672,
#         0.96093966]),
#  array([0.92434   , 0.85723387, 0.80562589, ..., 0.97482634, 0.98279757,
#         0.91198656]),
#  array([0.71680656, 0.76550114, 0.79386811, ..., 0.95349745, 0.89170437,
#         0.75897772]),
#  array([0.98412837, 0.98606466, 0.99449783, ..., 0.98096568, 0.98405556,
#         0.9877855 ]),
#  array([0.91085144, 0.91118214, 0.92669434, ..., 0.99794627, 0.98827941,
#         0.98959606]),
#  array([1.00131151, 1.00291763, 1.01851407, ..., 0.97215866, 0.97673162,
#         0.97315563]),
#  array([0.98776921, 0.98988216, 1.00578566, ..., 1.01362544, 1.01096134,
#         1.01353119]),
#  array([0.98740373, 1.01034958, 1.01087   , ..., 1.14529564, 1.0996888 ,
#         1.11119739]),
#  array([1.0214258 , 1.02832911, 1.03407562, ..., 0.98961299, 0.99954499,
#         1.00314134]),
#  array([1.03090158, 1.01356844, 0.99317826, ..., 1.04322505, 1.04476324,
#         1.05502656]),
#  array([0.99873751, 0.9789535 , 0.98842505, ..., 0.97296931, 0.96600121,
#         0.94340985]),
#  array([0.90904787, 0.92645913, 0.95783901, ..., 0.99425371, 0.97142085,
#         0.97892361]),
#  array([0.96600899, 0.98878863, 0.97402287, ..., 0.99559237, 0.98659803,
#         1.02256382]),
#  array([0.99543414, 0.9708381 , 0.97379217, ..., 0.96968989, 0.96155633,
#         0.96622025]),
#  array([1.04741928, 1.07111618, 1.06004261, ..., 1.08663977, 1.06854369,
#         1.01677075]),
#  array([1.12771568, 1.1324987 , 1.14128661, ..., 0.99870259, 1.01080918,
#         1.02835174]),
#  array([1.32626868, 1.31029125, 1.29958111, ..., 1.00754005, 0.9741772 ,
#         0.97882165]),
#  array([1.12027928, 1.09235773, 1.08037986, ..., 1.00189355, 1.04612559,
#         0.99808788]),
#  array([1.09373267, 1.08998898, 1.08385386, ..., 1.06851695, 1.04056448,
#         1.00976743]),
#  array([1.20412539, 1.17575018, 1.15990228, ..., 1.0358723 , 1.01428953,
#         1.02809613]),
#  array([1.01338676, 1.02475873, 1.04212775, ..., 1.00627834, 1.01172057,
#         0.994619  ]),
#  array([1.12974931, 1.12773027, 1.12721894, ..., 1.02720416, 1.05562601,
#         1.10456661]),
#  array([1.04280665, 1.10260677, 1.14671032, ..., 1.08097772, 1.05856262,
#         0.99478904]),
#  array([1.07493501, 1.04771024, 1.02913926, ..., 1.05824929, 1.07175517,
#         1.03508726]),
#  array([1.00830892, 1.01013022, 1.02016858, ..., 0.99107521, 0.99112368,
#         0.99090609]),
#  array([1.11131626, 1.11727766, 1.1165949 , ..., 1.05419083, 1.0380456 ,
#         1.0461466 ]),
#  array([1.02260202, 1.03787826, 1.05850642, ..., 1.02277085, 1.01417346,
#         1.00620171]),
#  array([1.05837844, 1.05164761, 1.0384823 , ..., 1.01717924, 1.01509951,
#         1.02268939]),
#  array([1.03279669, 1.07454315, 1.16807006, ..., 1.00012677, 1.02194049,
#         1.00223169]),
#  array([1.1433921 , 1.17380532, 1.22538762, ..., 1.02303897, 1.04045474,
#         1.01873604]),
#  array([1.03880078, 1.04991091, 1.05637929, ..., 1.02757428, 1.04230054,
#         1.02327375]),
#  array([1.05682179, 1.05490145, 1.02551313, ..., 1.20544091, 1.21103662,
#         1.21321963]),
#  array([1.01434   , 1.02647638, 1.05395934, ..., 0.94896074, 0.91012075,
#         0.87447782]),
#  array([1.00304038, 1.00471724, 0.99890092, ..., 0.99349694, 0.9935736 ,
#         0.99231788]),
#  array([1.00830095, 1.00695691, 1.00937431, ..., 1.00100751, 0.99607884,
#         0.99966092]),
#  array([1.15192902, 1.13094881, 1.12355181, ..., 0.98413864, 0.98274098,
#         0.98444347]),
#  array([1.03933239, 1.05347406, 1.0507146 , ..., 0.67038737, 0.77428316,
#         0.90524581]),
#  array([0.98945667, 1.01258475, 1.01709418, ..., 1.10612175, 1.26423809,
#         1.28679032]),
#  array([1.0147055 , 1.00688281, 1.0192459 , ..., 0.84919664, 0.84582327,
#         0.85450242]),
#  array([0.91973603, 0.9611604 , 0.9604379 , ..., 0.92442371, 0.94638688,
#         1.09510285]),
#  array([0.99991747, 0.99131551, 0.99767377, ..., 0.98226261, 0.96154176,
#         0.93767255]),
#  array([1.05834379, 1.05923002, 1.03382516, ..., 1.01820199, 1.01441192,
#         1.05916958]),
#  array([1.02505021, 0.99091388, 1.0118498 , ..., 1.01217965, 1.04209876,
#         1.03024133]),
#  array([1.00175357, 1.0026205 , 1.00508197, ..., 0.997959  , 0.97712476,
#         0.94611306]),
#  array([1.02945543, 1.02090904, 1.00909541, ..., 0.98053132, 1.041316  ,
#         1.07486483]),
#  array([0.95267725, 0.9597798 , 0.96600007, ..., 1.04602549, 1.03757646,
#         1.06357795]),
#  array([0.99209896, 0.99381765, 0.98772222, ..., 1.03096575, 1.00957013,
#         1.01664507]),
#  array([1.00652234, 1.00880099, 1.00086888, ..., 1.04985484, 1.06032228,
#         1.05505535]),
#  array([1.00691345, 1.00560574, 1.00190016, ..., 1.00914242, 0.99006769,
#         0.98162487]),
#  array([0.95766712, 0.9630616 , 0.93866523, ..., 1.25250079, 1.21575784,
#         1.18092495]),
#  array([0.99315877, 1.0033934 , 1.01791956, ..., 1.01073357, 1.00331581,
#         0.98553149]),
#  [],
#  array([1.01058367, 1.01185223, 0.99613214, ..., 1.0183234 , 1.00960788,
#         0.98742658]),
#  array([0.98372191, 1.01576575, 0.98243788, ..., 1.01291507, 0.99031774,
#         0.9862901 ]),
#  array([1.00625223, 1.0065607 , 0.99956489, ..., 1.00851607, 1.01209818,
#         1.03626879]),
#  array([1.01438735, 1.01772902, 0.98120473, ..., 0.9969964 , 1.00268764,
#         0.99371219]),
#  array([0.99313593, 0.99611019, 0.99170011, ..., 1.03422922, 1.02130732,
#         1.0401012 ]),
#  array([0.99587473, 1.00808386, 1.00894662, ..., 1.02362121, 1.0123189 ,
#         1.02657971]),
#  [],
#  array([0.96563798, 0.95409004, 0.96161524, ..., 1.03415983, 1.04852687,
#         1.0460289 ]),
#  array([0.98823074, 0.99185562, 1.00119031, ..., 1.09617711, 1.09216666,
#         1.11370525]),
#  array([1.03498624, 1.00126543, 0.9640002 , ..., 0.99510239, 1.00681029,
#         0.99909196]),
#  [],
#  array([1.01382713, 1.02509901, 1.03433241, ..., 0.96661616, 0.98620028,
#         0.98761765]),
#  array([0.99114477, 0.99897998, 1.0168202 , ..., 1.01083735, 1.04617907,
#         1.02684423]),
#  array([1.09168939, 1.05391784, 1.03082667, ..., 1.11317423, 1.10005128,
#         1.11022193]),
#  array([0.96978409, 0.99957502, 1.00810618, ..., 0.94324282, 0.95012731,
#         1.17025333]),
#  array([0.9742609 , 0.94826528, 0.96489546, ..., 1.04966716, 1.03673418,
#         1.00731949]),
#  array([0.99429439, 0.98610669, 0.98501212, ..., 1.00020181, 0.98698826,
#         0.97897618]),
#  array([0.96601178, 0.97047885, 0.97203003, ..., 1.00082915, 0.98964148,
#         0.99443931]),
#  array([0.84886847, 0.84654477, 0.87792196, ..., 1.03369652, 1.03249596,
#         1.01636083]),
#  array([1.0835928 , 0.94377133, 0.88439151, ..., 1.02573233, 1.01756748,
#         0.99883182]),
#  array([0.88556305, 0.91051402, 0.89336635, ..., 0.97201801, 0.98240463,
#         0.97747762]),
#  array([0.73431939, 0.72277804, 0.72245575, ..., 0.99216009, 1.01437306,
#         0.29517374]),
#  array([0.85160689, 0.81452438, 0.80245517, ..., 0.99864082, 0.98390801,
#         0.9697314 ]),
#  array([0.76847609, 0.77351609, 0.78792842, ..., 1.0933973 , 1.05866666,
#         1.0493736 ]),
#  array([0.83321152, 0.82421644, 0.80620462, ..., 1.04201695, 1.03650187,
#         1.0299124 ]),
#  array([0.88406575, 0.88077043, 0.87736476, ..., 0.99966409, 1.00320426,
#         1.04184819]),
#  array([0.92152939, 0.88819081, 0.86819872, ..., 1.10499825, 1.10425377,
#         1.07374605]),
#  array([0.90910621, 0.91448639, 0.94248242, ..., 1.02700047, 1.03784295,
#         1.02064323]),
#  array([0.9100416 , 0.91767549, 0.96603226, ..., 0.98473996, 1.00516742,
#         1.00567989]),
#  array([0.94795748, 0.94471514, 0.99793852, ..., 0.92342362, 0.86893886,
#         0.80452405]),
#  array([0.98791413, 0.99063834, 0.97908636, ..., 1.00316168, 0.96789519,
#         0.97172423]),
#  array([0.99786066, 0.98620337, 0.97063578, ..., 0.79412668, 0.70325325,
#         0.65136741]),
#  array([1.02740143, 1.03195642, 1.01440324, ..., 0.85780751, 1.02813803,
#         1.16928024]),
#  [],
#  array([1.01632467, 1.00456008, 0.9787249 , ..., 1.12711087, 1.14326987,
#         1.14528449]),
#  array([0.94173199, 0.9604287 , 0.9718916 , ..., 1.07466544, 1.07227963,
#         1.09029778]),
#  array([0.98167871, 0.99192062, 1.00670916, ..., 0.7982662 , 0.89387197,
#         1.11664753]),
#  array([0.93669016, 0.92670092, 0.91456311, ..., 0.92373101, 0.89939014,
#         0.92336041]),
#  array([1.00309419, 0.98779721, 1.01131626, ..., 0.85348655, 0.82442078,
#         0.7460119 ]),
#  array([1.01467495, 1.02254513, 1.02969493, ..., 0.8257743 , 0.79617913,
#         0.89932551]),
#  array([0.88982079, 0.92932247, 0.93395046, ..., 1.2086394 , 1.22384481,
#         1.25381721]),
#  array([0.98159682, 0.99143294, 0.99905636, ..., 1.17136489, 1.24446667,
#         1.25868131]),
#  array([1.02483082, 0.98218235, 0.98959819, ..., 1.24003601, 1.21748813,
#         1.17956174]),
#  array([1.0023105 , 0.99834566, 1.01019601, ..., 0.92884811, 0.93916592,
#         0.95665906]),
#  array([0.99292143, 1.0108743 , 1.0102355 , ..., 1.0004879 , 0.95999448,
#         0.9259695 ]),
#  array([0.95438401, 0.95047654, 0.95659567, ..., 1.04751709, 1.07060788,
#         1.09393554]),
#  array([1.02087632, 1.00733786, 1.00684668, ..., 0.99930773, 0.98614717,
#         0.99038306]),
#  array([1.00661629, 1.05242199, 1.11291501, ..., 0.94959338, 0.94807619,
#         0.93801583]),
#  array([1.0072617 , 1.03650709, 1.0622221 , ..., 1.02552181, 1.05631366,
#         1.0510129 ]),
#  array([0.95890068, 0.97333153, 0.96430437, ..., 0.97527065, 0.97539272,
#         1.20970291]),
#  array([1.00135149, 0.99757557, 0.99407514, ..., 1.01517366, 1.01171442,
#         1.01310573]),
#  array([1.00209031, 1.00415863, 1.00665729, ..., 1.0232011 , 1.01546763,
#         1.02007827]),
#  array([0.89823209, 0.99225276, 1.0200033 , ..., 1.01460799, 1.02766094,
#         1.03219016]),
#  array([1.0279616 , 1.00033134, 0.99631488, ..., 1.00229301, 0.97725793,
#         1.01973263]),
#  array([0.99319579, 0.98738617, 0.99349948, ..., 1.04009691, 1.06816991,
#         1.07311787]),
#  array([0.99533697, 1.01449255, 0.97362764, ..., 1.01787181, 1.01119415,
#         1.03632348]),
#  array([1.04098755, 1.05197356, 1.07216507, ..., 1.06378928, 1.10441526,
#         1.11752093]),
#  array([0.93455057, 0.85445498, 0.78411981, ..., 0.96791089, 0.99219212,
#         0.972915  ]),
#  array([0.95401517, 0.95280643, 0.946516  , ..., 1.03828212, 1.01093628,
#         0.93466528]),
#  array([0.93452627, 0.97950904, 0.95538562, ..., 1.17742698, 1.18646241,
#         1.18551317]),
#  array([1.03801266, 1.02990721, 1.0083185 , ..., 0.9449711 , 1.02959524,
#         1.04281037]),
#  array([0.93337555, 0.88072834, 0.90904926, ..., 1.02290407, 0.98622731,
#         0.97524291]),
#  array([0.87079793, 0.93853612, 0.93836801, ..., 1.0267727 , 1.00207306,
#         1.03331956]),
#  array([0.94924228, 0.98312595, 0.99400083, ..., 1.00785857, 1.04916369,
#         0.98905823]),
#  array([0.99844372, 0.98603855, 0.98308463, ..., 1.01789998, 1.07061737,
#         1.12706088]),
#  array([0.96490062, 1.00324656, 1.02499934, ..., 1.01108024, 1.02482101,
#         1.02600898]),
#  array([1.05369538, 1.04261986, 1.03040444, ..., 1.06706952, 1.05110973,
#         1.02987056]),
#  array([0.99742006, 1.01534581, 1.0204354 , ..., 1.01372055, 1.00899874,
#         0.99312163]),
#  array([0.89037181, 0.96515686, 1.03459329, ..., 1.07375695, 1.10746132,
#         1.098577  ]),
#  array([1.01302872, 0.96769641, 0.96131989, ..., 1.08003312, 1.05295845,
#         1.09907398]),
#  array([0.93301762, 1.01734545, 1.02889559, ..., 0.99586147, 0.95341636,
#         0.90619396]),
#  array([1.05614701, 1.05801696, 1.04177439, ..., 1.18069581, 1.10574607,
#         1.04554837]),
#  array([0.96567964, 0.9713927 , 0.97039472, ..., 1.34636472, 1.45607032,
#         1.48084072]),
#  array([0.96546716, 1.03683991, 1.00276719, ..., 1.08260521, 1.4137652 ,
#         1.40330661]),
#  array([0.98777429, 0.97785253, 0.98873239, ..., 1.00553428, 1.00080398,
#         1.00850945]),
#  array([1.0013061 , 1.00944261, 1.01414174, ..., 1.00946206, 1.00398682,
#         1.01562408]),
#  array([1.04491369, 1.04293866, 1.04678549, ..., 0.98689105, 0.98183179,
#         0.99429931]),
#  array([1.01436187, 1.02051658, 1.01757519, ..., 0.98470062, 0.99459542,
#         0.98379167]),
#  array([1.10947559, 1.09845503, 1.08066977, ..., 0.99137584, 0.95841085,
#         0.90998044]),
#  array([0.93963353, 0.96969779, 0.98974655, ..., 0.97554942, 0.97752976,
#         1.00472085]),
#  array([0.97522938, 0.98977185, 1.00425006, ..., 1.02041805, 1.01978296,
#         1.02341961]),
#  array([1.01302028, 0.98789126, 0.95596212, ..., 1.07442662, 1.04264159,
#         1.04995128]),
#  array([0.77843082, 0.75864911, 0.73912824, ..., 0.998708  , 0.98728364,
#         0.960434  ]),
#  array([0.93933601, 0.9407808 , 0.94105824, ..., 1.12118636, 1.07442475,
#         1.13533822]),
#  array([1.01022131, 1.05454274, 1.09208269, ..., 1.08949109, 1.14363366,
#         1.13710564]),
#  array([1.00562248, 1.01186485, 1.00648098, ..., 0.98186695, 0.98424734,
#         0.98576786]),
#  array([0.9647826 , 0.95331824, 0.96378201, ..., 0.9984782 , 1.00095815,
#         1.00387284]),
#  array([1.04098422, 1.06994693, 1.1094519 , ..., 1.04088495, 0.98645503,
#         0.91223909]),
#  array([1.12540101, 1.13666247, 1.13580669, ..., 1.01473957, 0.97184381,
#         0.94686003]),
#  array([1.0072745 , 0.9823007 , 0.98143951, ..., 1.00072266, 1.01117399,
#         1.01714829]),
#  array([0.93579034, 0.93290931, 0.92555232, ..., 0.98748126, 1.03363545,
#         1.09921547]),
#  array([1.02519942, 1.03127902, 1.01505447, ..., 0.98019606, 0.96127608,
#         0.99389787]),
#  array([1.09640539, 1.0156593 , 1.00425387, ..., 0.98994992, 1.02993864,
#         1.02660325]),
#  array([1.00504054, 1.03379945, 1.03276915, ..., 1.01209679, 1.01602648,
#         1.01705178]),
#  array([1.02990812, 1.08519371, 1.07787381, ..., 1.03350818, 1.04559169,
#         1.12243653]),
#  array([1.00588986, 1.02508115, 1.01303215, ..., 1.03865072, 1.01792828,
#         1.00534132]),
#  array([0.99153583, 0.97718208, 0.97772117, ..., 0.98316096, 0.98325969,
#         0.9917174 ]),
#  array([0.97898604, 0.96471376, 0.97131367, ..., 0.9385627 , 0.91174363,
#         0.91898349]),
#  array([0.97380457, 0.97108004, 0.97487474, ..., 0.86523   , 0.84087661,
#         0.83199714]),
#  array([0.97679144, 1.00842039, 1.00929121, ..., 0.98404437, 1.01142439,
#         1.04757005]),
#  [],
#  array([0.96531466, 1.01576422, 1.0401975 , ..., 1.00827302, 0.99026852,
#         0.99916734]),
#  array([0.99846676, 0.9974163 , 1.02444256, ..., 0.99455834, 1.0125555 ,
#         1.02926335]),
#  array([0.95746339, 0.94297126, 0.95896323, ..., 1.00239592, 1.00922402,
#         1.03489453]),
#  array([0.98423947, 0.99777243, 0.99559278, ..., 1.06507296, 1.05350234,
#         1.01393382]),
#  array([0.88248884, 0.86353519, 0.87007873, ..., 1.18624587, 1.19002298,
#         1.16403527]),
#  array([0.89244392, 0.90528044, 0.92861312, ..., 0.99491753, 0.99127126,
#         0.98860158]),
#  array([1.0584048 , 1.03115409, 1.02225672, ..., 1.04022219, 1.02622796,
#         1.00157349]),
#  array([1.0434546 , 1.04463437, 1.04230997, ..., 1.03897913, 1.07529581,
#         1.0755477 ]),
#  array([0.99195766, 1.00262989, 1.00302904, ..., 1.08820588, 1.05102033,
#         1.00192282]),
#  ...]

# %%
def resample_spectra(spectrum, camera, verbose):

    spec_resample, spec_errs_resample = spectres(regrid,  spectrum['wave_norm_'+str(camera)], spectrum['sob_norm_'+str(camera)], spec_errs= spectrum['uob_norm_'+str(camera)],verbose=verbose) 

    return spec_resample, spec_errs_resample

#for Li pick camera 3

# %%
#open an empty dict to store the results 
resampled_spectra_collection = {}
resampled_spectra_collection['spec_resample'] = []

resampled_error_collection = {}
resampled_error_collection['error_resample'] = []

# %%
for sobject_id in sobject_ids:
    #this is the normalised resampled spectra 
    temp_spectrum = resample_spectra(read_spectra(sobject_id), 3, False)
    temp_spectrum[0][np.isnan(temp_spectrum[0])] = 1 #padding 
    resampled_spectra_collection['spec_resample'].append(temp_spectrum[0])

    #these are the error spectra
    #calculate mean error for padding 

    non_na_values = temp_spectrum[1][~np.isnan(temp_spectrum[1])]
    mean_error = np.mean(non_na_values)

    temp_spectrum[1][np.isnan(temp_spectrum[1])] = mean_error
    resampled_error_collection['error_resample'].append(temp_spectrum[1])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_22153/3802133152.py in <module>
#       1 for sobject_id in sobject_ids:
#       2     #this is the normalised resampled spectra
# ----> 3     temp_spectrum = resample_spectra(read_spectra(sobject_id), 3, False)
#       4     temp_spectrum[0][np.isnan(temp_spectrum[0])] = 1 #padding
#       5     resampled_spectra_collection['spec_resample'].append(temp_spectrum[0])
#
# /tmp/ipykernel_22153/3108038632.py in resample_spectra(spectrum, camera, verbose)
#       1 def resample_spectra(spectrum, camera, verbose):
#       2
# ----> 3     spec_resample, spec_errs_resample = spectres(regrid,  spectrum['wave_norm_'+str(camera)], spectrum['sob_norm_'+str(camera)], spec_errs= spectrum['uob_norm_'+str(camera)],verbose=verbose)
#       4
#       5     return spec_resample, spec_errs_resample
#
# ~/anaconda3/envs/masters-thesis/lib/python3.8/site-packages/spectres/spectral_resampling.py in spectres(new_wavs, spec_wavs, spec_fluxes, spec_errs, fill, verbose)
#      74     # Make arrays of edge positions and widths for the old and new bins
#      75
# ---> 76     old_edges, old_widths = make_bins(old_wavs)
#      77     new_edges, new_widths = make_bins(new_wavs)
#      78
#
# ~/anaconda3/envs/masters-thesis/lib/python3.8/site-packages/spectres/spectral_resampling.py in make_bins(wavs)
#       7     """ Given a series of wavelength points, find the edges and widths
#       8     of corresponding wavelength bins. """
# ----> 9     edges = np.zeros(wavs.shape[0]+1)
#      10     widths = np.zeros(wavs.shape[0])
#      11     edges[0] = wavs[0] - (wavs[1] - wavs[0])/2
#
# AttributeError: 'list' object has no attribute 'shape'
